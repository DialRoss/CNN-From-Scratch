# %% [markdown]
# ### Semaine 3 : Analyse avancée des modèles CNN
# ### Objectifs :
# #### - Comparer SGD, Adam, RMSprop
# #### - Visualiser courbes d’apprentissage, filtres, feature maps
# #### - Analyser matrice de confusion et erreurs
# #### - Étude d’ablation des composants clés

# %%
pip install seaborn

# %% [markdown]
# #### 1. Configuration de l'environnement

# %%
# Configuration initiale
import sys
import os
sys.path.append('C:/Users/Alien/Desktop/cnn-from-scratch/week3-advanced-training/src')

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import confusion_matrix

# Configuration de l'affichage
plt.rcParams['figure.figsize'] = (12, 8)
sns.set_style('whitegrid')
# %matplotlib inline

print("=== Notebook d'analyse CNN - Prêt à exécuter ===")

# %%
# Import des modules
from src.utils import load_mnist, augment_data
from src.layers import Conv2D, Dense, ReLU, Softmax, MaxPool2D, Flatten, Dropout
from src.model import Sequential
from src.optimizers import SGD, Adam, RMSprop, LearningRateScheduler
from src.callbacks import EarlyStopping

print("Tous les modules importés avec succès!")
# Out:
# === Notebook d'analyse CNN - Prêt à exécuter ===
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 21
#      17 print("=== Notebook d'analyse CNN - Prêt à exécuter ===")
#      19 # %%
#      20 # Import des modules
# ---> 21 from utils import load_mnist, augment_data
#      22 from layers import Conv2D, Dense, ReLU, Softmax, MaxPool2D, Flatten, Dropout
#      23 from model import Sequential
#
# File C:\Users/Alien/Desktop/cnn-from-scratch/week3-advanced-training/src\utils.py:11
#       9 from time import time
#      10 import pandas as pd
# ---> 11 from callbacks import LearningRateScheduler
#      13 def load_mnist():
#      14     url = 'https://github.com/mnielsen/neural-networks-and-deep-learning/raw/master/data/mnist.pkl.gz'
#
# ...

# %% [markdown]
# #### 1. Chargement des données
